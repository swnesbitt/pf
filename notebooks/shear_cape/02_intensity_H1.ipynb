# %% [markdown]
# # 02 — H1: intensity vs shear at fixed CAPE (A2)
# For each response: (i) median composite over (CAPE×shear), land/ocean; (ii) the direct **fixed-CAPE** test — response vs shear by CAPE quartile (echo-tops should *rise*, PCTs *fall* with shear); (iii) the **extreme tail** (p90/p99) for the deepest/coldest. TRMM leads (consistent 16-dBZ sensitivity); GPM replicates.

# %%
import sys; sys.path.insert(0, '.')
from _shc import *
con = connect()

# %% [markdown]
# ### max 20-dBZ height [km]

# %%
plot_composite(con, 'ht20_km', mission='TRMM', label='max 20-dBZ height [km]')
plot_fixed_cape(con, 'ht20_km', mission='TRMM', label='max 20-dBZ height [km]')

# %% [markdown]
# ### max 30-dBZ height [km]

# %%
plot_composite(con, 'ht30_km', mission='TRMM', label='max 30-dBZ height [km]')
plot_fixed_cape(con, 'ht30_km', mission='TRMM', label='max 30-dBZ height [km]')

# %% [markdown]
# ### max 40-dBZ height [km]

# %%
plot_composite(con, 'ht40_km', mission='TRMM', label='max 40-dBZ height [km]')
plot_fixed_cape(con, 'ht40_km', mission='TRMM', label='max 40-dBZ height [km]')

# %% [markdown]
# ### min 85-GHz PCT [K]

# %%
plot_composite(con, 'min_pct_85_89', mission='TRMM', label='min 85-GHz PCT [K]')
plot_fixed_cape(con, 'min_pct_85_89', mission='TRMM', label='min 85-GHz PCT [K]')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ### min 37-GHz PCT [K]

# %%
plot_composite(con, 'min_pct_37', mission='TRMM', label='min 37-GHz PCT [K]')
plot_fixed_cape(con, 'min_pct_37', mission='TRMM', label='min 37-GHz PCT [K]')

# %% [markdown]
# ### Extreme tail (p99) — deepest 40-dBZ tops & coldest 37-GHz PCT

# %%
plot_composite(con,'ht40_km',mission='TRMM',label='max 40-dBZ height [km]',stat='p99')
plot_composite(con,'min_pct_37',mission='TRMM',label='min 37-GHz PCT [K]',stat='p99',cmap='turbo_r')

# %% [markdown]
# ### GPM replication (deep-layer responses)

# %%
plot_fixed_cape(con,'ht40_km',mission='GPM',label='max 40-dBZ height [km]')
plot_fixed_cape(con,'min_pct_37',mission='GPM',label='min 37-GHz PCT [K]')
