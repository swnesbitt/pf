# %% [markdown]
# # 04 — H3: stratiform rain area vs shear at fixed CAPE (A4)
# Stratiform area and area-fraction across (CAPE×shear), all features and within MCSs only (the stratiform region is an organized-system feature).

# %%
import sys; sys.path.insert(0, '.')
from _shc import *
con = connect()

# %% [markdown]
# ### Stratiform area & fraction — fixed-CAPE test

# %%
plot_fixed_cape(con,'strat_area_km2',mission='TRMM',label='stratiform area [km^2]')
plot_fixed_cape(con,'strat_area_frac',mission='TRMM',label='stratiform area fraction')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ### Within MCSs only

# %%
plot_composite(con,'strat_area_km2',mission='TRMM',label='stratiform area [km^2] (MCS)',
               where="AND feature_class='MCS'", conv_only=False)
plot_composite(con,'strat_area_km2',mission='GPM',label='stratiform area [km^2] (MCS)',
               where="AND feature_class='MCS'", conv_only=False)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
